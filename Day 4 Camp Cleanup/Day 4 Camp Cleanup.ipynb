# %%
import pandas as pd
import math

workdir = 'C:\\Users\\ed.deane\\OneDrive - Sabio Ltd\\Documents\\Customers\\IKEA\\Knowledge\\Python\\AdventOfCode\\Day 4 Camp Cleanup\\'

df = pd.read_csv(workdir+'input.txt', sep=',',header=None)

def within_range(txt1, txt2):
    ret = False
    t1a = int(txt1[0:txt1.index('-')])
    t1b = int(txt1[txt1.index('-')+1:])
    t2a = int(txt2[0:txt2.index('-')])
    t2b = int(txt2[txt2.index('-')+1:])
    
    if (t1a <= t2a and t1b >= t2b):
        ret = True
    if (t2a <= t1a and t2b >= t1b):
        ret = True
    
    return ret

df["in_range"] = (df.apply(lambda x: within_range(x[0],x[1]), axis=1))
df.loc[df["in_range"]]
# Out:
#          0      1  in_range
# 0    30-31   2-31      True
# 3    35-95  35-95      True
# 6    37-85  84-84      True
# 8    52-68  51-69      True
# 10    9-62  61-61      True
# ..     ...    ...       ...
# 990   6-33   5-33      True
# 991  34-34  13-34      True
# 993  33-64  49-61      True
# 994  37-45  36-52      True
# 997  41-66  27-67      True
#
# [444 rows x 3 columns]

# %%
def within_range(txt1, txt2):
    ret = False
    t1a = int(txt1[0:txt1.index('-')])
    t1b = int(txt1[txt1.index('-')+1:])
    t2a = int(txt2[0:txt2.index('-')])
    t2b = int(txt2[txt2.index('-')+1:])
    
    if (t1a <= t2a and t1b >= t2b):
        ret = True
    if (t2a <= t1a and t2b >= t1b):
        ret = True
    
    return ret

within_range("5-52","20-88")
# Out:
# False
