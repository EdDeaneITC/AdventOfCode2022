# %%
import pandas as pd

workdir = 'C:\\Users\\ed.deane\\Python\\AdventOfCode\\Day 6 Tuning Trouble\\'

df= pd.read_csv(workdir+'input.txt', header=None)

txt=df[0][0]
ctr = 0
lst = ['','','','','','','','','','','','','','']
print (len(lst))
for i in txt:
    ctr+=1
    # make the list up to include the newest entry and pop the oldest
    lst.pop()
    lst.insert(0,i)
    print (lst)
    
    if (len(set(lst)) == len(lst) and ctr > 13):
        print(ctr, len(set(lst)))
        break
# Out:
# 14
# ['d', '', '', '', '', '', '', '', '', '', '', '', '', '']
# ['c', 'd', '', '', '', '', '', '', '', '', '', '', '', '']
# ['b', 'c', 'd', '', '', '', '', '', '', '', '', '', '', '']
# ['c', 'b', 'c', 'd', '', '', '', '', '', '', '', '', '', '']
# ['s', 'c', 'b', 'c', 'd', '', '', '', '', '', '', '', '', '']
# ['b', 's', 'c', 'b', 'c', 'd', '', '', '', '', '', '', '', '']
# ['b', 'b', 's', 'c', 'b', 'c', 'd', '', '', '', '', '', '', '']
# ['l', 'b', 'b', 's', 'c', 'b', 'c', 'd', '', '', '', '', '', '']
# ['h', 'l', 'b', 'b', 's', 'c', 'b', 'c', 'd', '', '', '', '', '']
# ['h', 'h', 'l', 'b', 'b', 's', 'c', 'b', 'c', 'd', '', '', '', '']
# ['g', 'h', 'h', 'l', 'b', 'b', 's', 'c', 'b', 'c', 'd', '', '', '']
# ['d', 'g', 'h', 'h', 'l', 'b', 'b', 's', 'c', 'b', 'c', 'd', '', '']
# ['g', 'd', 'g', 'h', 'h', 'l', 'b', 'b', 's', 'c', 'b', 'c', 'd', '']
# ['s', 'g', 'd', 'g', 'h', 'h', 'l', 'b', 'b', 's', 'c', 'b', 'c', 'd']
# ...
